# %%
#Imports
from ultralytics import YOLO

# %%
#Load model
model = YOLO('C:/dragon egg/AnimalDetectionYolo/code/runs/detect/train/weights/last.pt')

# %%
#Train
results = model.train(data="config.yaml", epochs=3)
# Out:
# New https://pypi.org/project/ultralytics/8.3.33 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.28  Python-3.12.7 torch-2.5.1+cpu CPU (AMD Ryzen 7 5700U with Radeon Graphics)
# ...

# %%
#Validation
metrics = model.eval()
# Out:
# New https://pypi.org/project/ultralytics/8.3.31 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.28  Python-3.12.7 torch-2.5.1+cpu CPU (AMD Ryzen 7 5700U with Radeon Graphics)
# ...

# %%
#Predict/
base1 = 'C:/dragon egg/AnimalDetectionYolo/data/images/train/'
base2 = 'C:/dragon egg/AnimalDetectionYolo/Stuff/iwildcam2021-fgvc8/test/'
fileName = '8a0fc752-21bc-11ea-a13a-137349068a90'

results = model([base2+fileName+'.jpg'])
    # Process results list
for result in results:
    boxes = result.boxes  # Boxes object for bounding box outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs
    obb = result.obb  # Oriented boxes object for OBB outputs
    result.show()  # display to screen
    result.save(filename="result.jpg")
# Out:
# 0: 384x640 2 Ocellated turkeys, 190.4ms
# Speed: 9.6ms preprocess, 190.4ms inference, 10.5ms postprocess per image at shape (1, 3, 384, 640)
